# %% [markdown]
# <a href="https://colab.research.google.com/github/sabhashanki/CNN_Flower_Classification/blob/main/cnn_flower_image_classification_data_augmentations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h2 style='color:blue' align='center'>Data Augmentation To Address Overfitting In Flower Classification CNN</h2>

# %% [markdown]
# **In this notebook we will build a CNN to classify flower images. We will also see how our model overfits and how overfitting can be addressed using data augmentation. Data augmentation is a process of generating new training samples from current training dataset using transformations such as zoom, rotations, change in contrast etc**

# %% [markdown]
# Credits: I used tensorflow offical tutorial: https://www.tensorflow.org/tutorials/images/classification as a reference and made bunch of changes to make it simpler

# %% [markdown]
# In below image, 4 new training samples are generated from original sample using different transformations

# %% [markdown]
# <img src="daisy2.JPG" />

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %% [markdown]
# We will download flowers dataset from google website and store it locally. In below call it downloads the zip file (.tgz) in cache_dir which is . meaning the current folder

# %% [markdown]
# <h3 style='color:purple'>Load flowers dataset</h3>

# %%
dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"
data_dir = tf.keras.utils.get_file('flower_photos', origin=dataset_url,  cache_dir='.', untar=True)
# cache_dir indicates where to download data. I specified . which means current directory
# untar true will unzip it
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz
# 228818944/228813984 [==============================] - 1s 0us/step
# 228827136/228813984 [==============================] - 1s 0us/step

# %%
data_dir
# Out:
# './datasets/flower_photos'

# %%
import pathlib
data_dir = pathlib.Path(data_dir)
data_dir
# Out:
# PosixPath('datasets/flower_photos')

# %%
list(data_dir.glob('*/*.jpg'))[:5]
# Out:
# [PosixPath('datasets/flower_photos/tulips/16283125269_4cfae953f1.jpg'),
#  PosixPath('datasets/flower_photos/tulips/4590702749_e1df8e0c1b.jpg'),
#  PosixPath('datasets/flower_photos/tulips/2470177960_7bd67db186_n.jpg'),
#  PosixPath('datasets/flower_photos/tulips/4558912791_084e440365_m.jpg'),
#  PosixPath('datasets/flower_photos/tulips/2280950463_86510c2789_n.jpg')]

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 3670

# %%
roses = list(data_dir.glob('roses/*'))
roses[:5]
# Out:
# [PosixPath('datasets/flower_photos/roses/5212877807_a3ddf06a7c_n.jpg'),
#  PosixPath('datasets/flower_photos/roses/3292654244_4a220ab96f_m.jpg'),
#  PosixPath('datasets/flower_photos/roses/2408236801_f43c6bcff2.jpg'),
#  PosixPath('datasets/flower_photos/roses/5181899042_0a6ffe0c8a_n.jpg'),
#  PosixPath('datasets/flower_photos/roses/17953368844_be3d18cf30_m.jpg')]

# %%
PIL.Image.open(str(roses[1]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=240x240 at 0x7F7FCC371110>

# %%
tulips = list(data_dir.glob('tulips/*'))
PIL.Image.open(str(tulips[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x333 at 0x7F7FCCE3D8D0>

# %% [markdown]
# <h3 style='color:purple'>Read flowers images from disk into numpy array using opencv</h3>

# %%
flowers_images_dict = {
    'roses': list(data_dir.glob('roses/*')),
    'daisy': list(data_dir.glob('daisy/*')),
    'dandelion': list(data_dir.glob('dandelion/*')),
    'sunflowers': list(data_dir.glob('sunflowers/*')),
    'tulips': list(data_dir.glob('tulips/*')),
}

# %%
flowers_labels_dict = {
    'roses': 0,
    'daisy': 1,
    'dandelion': 2,
    'sunflowers': 3,
    'tulips': 4,
}

# %%
flowers_images_dict['roses'][:5]
# Out:
# [PosixPath('datasets/flower_photos/roses/5212877807_a3ddf06a7c_n.jpg'),
#  PosixPath('datasets/flower_photos/roses/3292654244_4a220ab96f_m.jpg'),
#  PosixPath('datasets/flower_photos/roses/2408236801_f43c6bcff2.jpg'),
#  PosixPath('datasets/flower_photos/roses/5181899042_0a6ffe0c8a_n.jpg'),
#  PosixPath('datasets/flower_photos/roses/17953368844_be3d18cf30_m.jpg')]

# %%
str(flowers_images_dict['roses'][0])
# Out:
# 'datasets/flower_photos/roses/5212877807_a3ddf06a7c_n.jpg'

# %%
img = cv2.imread(str(flowers_images_dict['roses'][0]))

# %%
img.shape
# Out:
# (240, 320, 3)

# %%
cv2.resize(img,(180,180)).shape
# Out:
# (180, 180, 3)

# %%
X, y = [], []

for flower_name, images in flowers_images_dict.items():
    for image in images:
        img = cv2.imread(str(image))
        resized_img = cv2.resize(img,(180,180))
        X.append(resized_img)
        y.append(flowers_labels_dict[flower_name])

# %%
X = np.array(X)
y = np.array(y)

# %% [markdown]
# <h3 style='color:purple'>Train test split</h3>

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %% [markdown]
# <h3 style='color:purple'>Preprocessing: scale images</h3>

# %%
X_train_scaled = X_train / 255
X_test_scaled = X_test / 255

# %% [markdown]
# <h3 style='color:purple'>Build convolutional neural network and train it</h3>

# %%
num_classes = 5

model = Sequential([
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
              
model.fit(X_train_scaled, y_train, epochs=30)
# Out:
# Epoch 1/30
# 86/86 [==============================] - 83s 945ms/step - loss: 1.3537 - accuracy: 0.4306
# Epoch 2/30
# 86/86 [==============================] - 79s 920ms/step - loss: 1.0449 - accuracy: 0.5879
# Epoch 3/30
# 86/86 [==============================] - 79s 916ms/step - loss: 0.8345 - accuracy: 0.6791
# Epoch 4/30
# 86/86 [==============================] - 79s 913ms/step - loss: 0.6782 - accuracy: 0.7496
# Epoch 5/30
# 86/86 [==============================] - 78s 913ms/step - loss: 0.4607 - accuracy: 0.8401
# Epoch 6/30
# 86/86 [==============================] - 79s 922ms/step - loss: 0.3048 - accuracy: 0.8972
# Epoch 7/30
# 86/86 [==============================] - 80s 934ms/step - loss: 0.1839 - accuracy: 0.9404
# Epoch 8/30
# 86/86 [==============================] - 79s 920ms/step - loss: 0.1545 - accuracy: 0.9473
# Epoch 9/30
# 86/86 [==============================] - 79s 916ms/step - loss: 0.1090 - accuracy: 0.9680
# Epoch 10/30
# 86/86 [==============================] - 79s 920ms/step - loss: 0.0537 - accuracy: 0.9880
# Epoch 11/30
# 86/86 [==============================] - 79s 918ms/step - loss: 0.0362 - accuracy: 0.9924
# Epoch 12/30
# 86/86 [==============================] - 79s 916ms/step - loss: 0.0570 - accuracy: 0.9866
# Epoch 13/30
# 86/86 [==============================] - 79s 916ms/step - loss: 0.0172 - accuracy: 0.9971
# Epoch 14/30
# 86/86 [==============================] - 79s 918ms/step - loss: 0.0336 - accuracy: 0.9880
# Epoch 15/30
# 86/86 [==============================] - 79s 914ms/step - loss: 0.0392 - accuracy: 0.9909
# Epoch 16/30
# 86/86 [==============================] - 79s 915ms/step - loss: 0.0144 - accuracy: 0.9971
# Epoch 17/30
# 86/86 [==============================] - 79s 915ms/step - loss: 0.0062 - accuracy: 0.9993
# Epoch 18/30
# 86/86 [==============================] - 79s 916ms/step - loss: 0.0077 - accuracy: 0.9993
# Epoch 19/30
# 86/86 [==============================] - 79s 915ms/step - loss: 0.0042 - accuracy: 0.9996
# Epoch 20/30
# 86/86 [==============================] - 80s 927ms/step - loss: 0.0070 - accuracy: 0.9993
# Epoch 21/30
# 86/86 [==============================] - 79s 920ms/step - loss: 0.0365 - accuracy: 0.9887
# Epoch 22/30
# 86/86 [==============================] - 79s 917ms/step - loss: 0.0791 - accuracy: 0.9738
# Epoch 23/30
# 86/86 [==============================] - 79s 916ms/step - loss: 0.0391 - accuracy: 0.9906
# Epoch 24/30
# 86/86 [==============================] - 79s 918ms/step - loss: 0.0167 - accuracy: 0.9967
# Epoch 25/30
# 86/86 [==============================] - 80s 931ms/step - loss: 0.0081 - accuracy: 0.9982
# Epoch 26/30
# 86/86 [==============================] - 80s 929ms/step - loss: 0.0041 - accuracy: 0.9996
# Epoch 27/30
# 86/86 [==============================] - 79s 921ms/step - loss: 0.0066 - accuracy: 0.9993
# Epoch 28/30
# 86/86 [==============================] - 81s 937ms/step - loss: 0.0034 - accuracy: 0.9996
# Epoch 29/30
# 86/86 [==============================] - 80s 926ms/step - loss: 0.0035 - accuracy: 0.9996
# Epoch 30/30
# 86/86 [==============================] - 80s 926ms/step - loss: 0.0028 - accuracy: 0.9996

# %%
model.evaluate(X_test_scaled,y_test)
# Out:
# 29/29 [==============================] - 8s 260ms/step - loss: 2.6625 - accuracy: 0.6471
# [2.6625473499298096, 0.6470588445663452]

# %% [markdown]
# **Here we see that while train accuracy is very high (99%), the test accuracy is significantly low (66.99%) indicating overfitting. Let's make some predictions before we use data augmentation to address overfitting**

# %%
predictions = model.predict(X_test_scaled)
predictions
# Out:
# array([[ -3.60968   ,   8.744464  ,   1.3351008 , -10.533598  ,
#          -7.152362  ],
#        [ -8.004337  ,  -2.025955  ,   5.3539963 ,  -4.388795  ,
#          -2.3734317 ],
#        [  0.11977051, -11.656444  ,   4.4838214 ,  -3.1767936 ,
#          -5.6860256 ],
#        ...,
#        [  2.731309  ,  -0.8150289 , -19.938337  ,  -1.7103517 ,
#           1.5014442 ],
#        [  9.999434  ,  -5.4303    ,  -7.238821  ,  -6.8148174 ,
#           4.552859  ],
#        [ -2.430842  , -31.365599  ,   5.6635036 ,  15.078707  ,
#          -5.285542  ]], dtype=float32)

# %%
score = tf.nn.softmax(predictions[0])

# %%
np.argmax(score)
# Out:
# 1

# %%
y_test[0]
# Out:
# 1

# %% [markdown]
# <h3 style='color:purple'>Improve Test Accuracy Using Data Augmentation</h3>

# %%
data_augmentation = keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal", 
                                                 input_shape=(img_height, 
                                                              img_width,
                                                              3)),
    layers.experimental.preprocessing.RandomRotation(0.1),
    layers.experimental.preprocessing.RandomZoom(0.1),
  ]
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-c8e0063429ed> in <module>()
#       2   [
#       3     layers.experimental.preprocessing.RandomFlip("horizontal",
# ----> 4                                                  input_shape=(img_height,
#       5                                                               img_width,
#       6                                                               3)),
#
# NameError: name 'img_height' is not defined

# %% [markdown]
# **Original Image**

# %%
plt.axis('off')
plt.imshow(X[0])

# %% [markdown]
# **Newly generated training sample using data augmentation**

# %%
plt.axis('off')
plt.imshow(data_augmentation(X)[0].numpy().astype("uint8"))

# %% [markdown]
# <h3 style='color:purple'>Train the model using data augmentation and a drop out layer</h3>

# %%
num_classes = 5

model = Sequential([
  data_augmentation,
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
              
model.fit(X_train_scaled, y_train, epochs=30)

# %%
model.evaluate(X_test_scaled,y_test)

# %% [markdown]
# **You can see that by using data augmentation and drop out layer the accuracy of test set predictions is increased to 73.74%**
